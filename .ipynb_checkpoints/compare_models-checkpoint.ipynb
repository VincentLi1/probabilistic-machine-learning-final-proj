# %% [markdown]
# Present the results of the different models on the train, validate, and test sets

# %%
import matplotlib.pyplot as plt
import numpy as np
import json

# %%
MODELS = ["sgd", "swa"] #"swag", "bacs", "abn"]
colors = ["skyblue", "orange", "green"]

# %%
results = []

for model in MODELS:
    with open(f"results/{model}_results.json") as f:
        results.append(json.load(f))

# %%
print(results)
# Out:
# [{'brightness-1': 0.1096716821193695, 'brightness-2': 0.09285996854305267, 'contrast-1': 0.03728243708610535, 'contrast-2': 0.026602057740092278, 'defocus_blur-1': 0.07407041639089584, 'defocus_blur-2': 0.0644778460264206}, {'brightness-1': 0.13172468543052673, 'brightness-2': 0.1071004793047905, 'contrast-1': 0.045490507036447525, 'contrast-2': 0.032337818294763565, 'defocus_blur-1': 0.08880538493394852, 'defocus_blur-2': 0.08069620281457901}]

# %%
labels = ["Brightness", "Contrast", "Defocus"]

filtered_results = [[results[i]["brightness-1"], results[i]["contrast-1"], results[i]["defocus_blur-1"]] for i in range(len(MODELS))]

x = np.arange(len(labels))
width = 0.25

# Plot
for i in range(len(MODELS)):
    plt.bar(x - width*((len(MODELS)-1)*0.5-i), filtered_results[i], width, label=MODELS[i], color=colors[i])

# Labels and formatting
plt.xlabel('Corruption')
plt.ylabel('Accuracy (Propor')
plt.title('Accuracy of Image Models on Corrupted Test Set\n (Train ImageNet, Test ImageNet-C)')
plt.xticks(x, labels)
plt.legend(title="Solver")
plt.tight_layout()
plt.show()
